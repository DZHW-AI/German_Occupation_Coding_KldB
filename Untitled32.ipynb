# %% [markdown]
# <a href="https://colab.research.google.com/github/DZHW-AI/German_Occupation_Coding_KldB/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("tensor_sarcasm.csv")
dff = pd.read_csv("sacarsmNew.csv")

# %%
df
# Out:
#       -0.85339415  -1.2205021  -0.34107935  -0.0048369  0.39526722  \
# 0       -0.757817   -1.166240    -0.387660    0.012612    0.585108
# 1       -0.939077   -1.260048    -0.276478    0.046626    0.497477
# 2       -0.727207   -1.194471    -0.300707    0.108128    0.450256
# 3       -0.824916   -1.174847    -0.393120    0.093283    0.468444
# 4       -0.883615   -1.179589    -0.616480   -0.122301    0.297389
# ...           ...         ...          ...         ...         ...
# 8020    -0.758722   -1.255940    -0.485153    0.079527    0.553889
# 8021    -0.907657   -1.333902    -0.444477    0.012376    0.612992
# 8022    -0.869412   -1.106203    -0.486555   -0.056493    0.530685
# 8023    -0.837789   -1.100666    -0.347108    0.017647    0.494162
# 8024    -0.907818   -1.230616    -0.357069   -0.015333    0.568294
#
#       -0.47470695  -0.97457105  0.9389285  0.95353043  -0.20999208  ...  \
# 0       -0.468283    -0.894903   0.891115    0.997197    -0.161906  ...
# ...

# %%
len(dff)
# Out:
# 8004

# %%
import numpy as np
#y=np.array(dff.is_finished)
y=dff.humor

# %%
y
y = y.iloc[1:]

# %%
len(tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bb441b96b6d3> in <module>
# ----> 1 len(tensor)
#
# NameError: name 'tensor' is not defined

# %%
print("Tensor details:")
print(f"Shape: {df.shape}")
#print(f"Data type: {df.dtype}")
print(f"Number of elements: {df.size}")
print(f"Number of dimensions: {df.ndim}")
#print(f"Memory used (bytes): {text_representations.nbytes}")
for i in range(df.ndim):
    print(f"Dimension {i+1}: {df.shape[i]}")
# Out:
# Tensor details:
# Shape: (8025, 768)
# Number of elements: 6163200
# Number of dimensions: 2
# Dimension 1: 8025
# Dimension 2: 768

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# Load the tensor from the CSV file
input_file = 'tensor_humor.csv'
tensor = pd.read_csv(input_file)

# Apply PCA to reduce dimensionality
n_components = 100  # You can change this to the desired number of dimensions
pca = PCA(n_components)
reduced_tensor = pca.fit_transform(df)

# Save the reduced tensor to a new CSV file
# output_file = 'reduced_tensor.csv'
# pd.DataFrame(reduced_tensor).to_csv(output_file, index=False)

# %%
# !pip install autoPyTorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.9/711.9 KB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 90.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 KB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 85.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 55.8 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from autoPyTorch.api.tabular_classification import TabularClassificationTask

# %%
X_train, X_val, y_train, y_val = train_test_split(reduced_tensor, y, test_size=0.2, random_state=42)
X_train = pd.DataFrame(X_train)
X_val = pd.DataFrame(X_val)
api = TabularClassificationTask()
api.search(
    X_train=X_train,
    y_train=y_train,
    X_test=X_val,
    y_test=y_val,
    optimize_metric='accuracy',
    total_walltime_limit=300,
    func_eval_time_limit_secs=50
)
y_pred = api.predict(X_val)
score = api.score(y_pred, y_val)
print("Accuracy score", score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8773291deafc> in <module>
# ----> 1 X_train, X_val, y_train, y_val = train_test_split(reduced_tensor, y, test_size=0.2, random_state=42)
#       2 X_train = pd.DataFrame(X_train)
#       3 X_val = pd.DataFrame(X_val)
#       4 api = TabularClassificationTask()
#       5 api.search(
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     354     """
#     355     result = [_make_indexable(X) for X in iterables]
# ...

# %%
from google.colab import files
# Define a DataFrame with two columns
df = pd.DataFrame({'true': y_val, 'pred':  y_pred})

# Use the DataFrame.to_csv() method to save the DataFrame as a CSV file
df.to_csv('sentence_finetuned_300.csv')
files.download('sentence_finetuned_300.csv')
